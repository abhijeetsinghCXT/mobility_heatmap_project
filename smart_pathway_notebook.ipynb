# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijeetsinghCXT/mobility_heatmap_project/blob/main/smart_pathway_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Load Libraries and Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load dataset
file_path = 'smart_mobility_dataset.csv'
try:
    df = pd.read_csv(file_path)
    print(f"✅ Dataset '{file_path}' loaded successfully!")
    df.head()
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
    print("Please make sure it is uploaded to your Colab session's file directory.")
# Out:
# ✅ Dataset 'smart_mobility_dataset.csv' loaded successfully!

# %% [markdown]
# ### **Perform Exploratory Data Analysis**

# %%
print("--- Dataset Information ---")
df.info()


print("\n--- Statistical Summary ---")
print(df.describe())

# Visualize the distribution of traffic conditions
print("\n--- Visualizing Traffic Condition Distribution ---")
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(8, 5))
sns.countplot(
    x='Traffic_Condition',
    data=df,
    order=['Low', 'Medium', 'High'],
    palette='viridis'
)
plt.title('Distribution of Traffic Conditions', fontsize=16)
plt.xlabel('Traffic Condition', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)
plt.show()
# Out:
# --- Dataset Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               5000 non-null   object
#  1   Latitude                5000 non-null   float64
#  2   Longitude               5000 non-null   float64
#  3   Vehicle_Count           5000 non-null   int64
#  4   Traffic_Speed_kmh       5000 non-null   float64
#  5   Road_Occupancy_%        5000 non-null   float64
#  6   Traffic_Light_State     5000 non-null   object
#  7   Weather_Condition       5000 non-null   object
#  8   Accident_Report         5000 non-null   int64
#  9   Sentiment_Score         5000 non-null   float64
#  10  Ride_Sharing_Demand     5000 non-null   int64
#  11  Parking_Availability    5000 non-null   int64
#  12  Emission_Levels_g_km    5000 non-null   float64
#  13  Energy_Consumption_L_h  5000 non-null   float64
#  14  Traffic_Condition       5000 non-null   object
# dtypes: float64(7), int64(4), object(4)
# memory usage: 586.1+ KB
#
# --- Statistical Summary ---
#           Latitude    Longitude  Vehicle_Count  Traffic_Speed_kmh  \
# count  5000.000000  5000.000000    5000.000000        5000.000000
# mean     40.749645   -73.847433     153.921200          42.111096
# std       0.086123     0.086204      83.523342          21.707720
# min      40.600016   -73.999987      10.000000           5.002789
# 25%      40.675403   -73.920281      80.000000          23.195752
# 50%      40.748875   -73.846058     156.000000          42.191599
# 75%      40.824735   -73.771685     226.000000          60.751760
# max      40.899972   -73.700159     299.000000          79.997556
#
#        Road_Occupancy_%  Accident_Report  Sentiment_Score  \
# count       5000.000000      5000.000000      5000.000000
# mean          54.748397         0.096000        -0.005652
# std           26.145238         0.294621         0.583790
# min           10.005031         0.000000        -0.999819
# 25%           32.089653         0.000000        -0.500154
# 50%           54.657297         0.000000        -0.010564
# 75%           77.581720         0.000000         0.500518
# max           99.999729         1.000000         0.999354
#
#        Ride_Sharing_Demand  Parking_Availability  Emission_Levels_g_km  \
# count          5000.000000           5000.000000           5000.000000
# mean             50.487800             24.613000            272.174927
# std              28.484426             14.532511            130.086372
# min               1.000000              0.000000             50.136855
# 25%              26.000000             12.000000            160.564433
# 50%              50.000000             24.000000            272.045513
# 75%              75.000000             37.000000            382.242055
# max              99.000000             49.000000            499.922663
#
#        Energy_Consumption_L_h
# count             5000.000000
# mean                17.343243
# std                  7.208277
# min                  5.003787
# 25%                 11.098761
# 50%                 17.153791
# 75%                 23.516595
# max                 29.995416
#
# --- Visualizing Traffic Condition Distribution ---
# /tmp/ipython-input-1970494559.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# ### **Generate Interactive Mobility Heatmap**

# %%
# Create a base map centered around the data's average coordinates
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
traffic_map = folium.Map(location=map_center, zoom_start=12)

# Prepare data for the HeatMap layer (lat, lon, weight)
heat_data = df[['Latitude', 'Longitude', 'Vehicle_Count']].values.tolist()

# Add the HeatMap layer to the map
HeatMap(heat_data, radius=15).add_to(traffic_map)

traffic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42a8f4ee898fcbac05ca488185d30d29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42a8f4ee898fcbac05ca488185d30d29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42a8f4ee898fcbac05ca488185d30d29 = L.map(
#                 &quot;map_42a8f4ee898fcbac05ca488185d30d29&quot;,
#                 {
#                     center: [40.74964523031779, -73.847433411381],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a1f089c1f46b3a25200b7f401052980 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a1f089c1f46b3a25200b7f401052980.addTo(map_42a8f4ee898fcbac05ca488185d30d29);
#
#
#             var heat_map_55ca16da4a1e4c95552010725d217888 = L.heatLayer(
#                 [[40.84227529289184, -73.70314869323049, 205.0], [40.8311193987152, -73.9873540904415, 202.0], [40.81954876392327, -73.73246185831279, 252.0], [40.72584887921568, -73.98013411315877, 37.0], [40.81326467769622, -73.96163054358502, 64.0], [40.64111174659454, -73.82509533565383, 125.0], [40.797138602855775, -73.79744494323391, 125.0], [40.81236201552322, -73.80175125224379, 130.0], [40.71700627798533, -73.78956236690148, 67.0], [40.87236437726417, -73.74020999668821, 12.0], [40.72249548994771, -73.83021193413559, 117.0], [40.79353376270334, -73.98380906075664, 12.0], [40.89474426796246, -73.74201042789959, 97.0], [40.82852824860497, -73.740942038757, 265.0], [40.64996313506776, -73.96601803074172, 187.0], [40.84620305175721, -73.88224990080543, 139.0], [40.73533093208594, -73.92847504458499, 298.0], [40.65288136201104, -73.84149222739376, 168.0], [40.75553084654906, -73.80884496929514, 188.0], [40.72540504944828, -73.98032961025936, 176.0], [40.762042045927856, -73.79413576366532, 38.0], [40.86821670420248, -73.97079464706162, 113.0], [40.76353773977935, -73.74218839187681, 56.0], [40.86608116490231, -73.96230427102891, 114.0], [40.86982813220531, -73.81569064335004, 17.0], [40.63173934063608, -73.80265007833458, 80.0], [40.82747192878859, -73.73075799751419, 231.0], [40.791042811421576, -73.97259663016875, 175.0], [40.65820558554093, -73.76058947344214, 188.0], [40.67393407647247, -73.90893909098952, 167.0], [40.89451760165618, -73.79768762808786, 91.0], [40.73719673516693, -73.90429715081174, 232.0], [40.71339651111975, -73.85200895536401, 218.0], [40.6874729675187, -73.99562660252461, 178.0], [40.65934012317005, -73.94228394775335, 184.0], [40.6904737391296, -73.97280138607873, 57.0], [40.87736130178688, -73.72960085038339, 52.0], [40.82978327892153, -73.81148010444957, 167.0], [40.60993112036775, -73.90914507367428, 197.0], [40.76596811933281, -73.9510657177867, 120.0], [40.72140396949303, -73.82165453145592, 100.0], [40.6900854463809, -73.83530903753847, 287.0], [40.74125197414136, -73.98342338997445, 69.0], [40.666989629209645, -73.81812960898553, 145.0], [40.64694350298437, -73.71582237527755, 284.0], [40.88031233248194, -73.86604614064487, 79.0], [40.87991608617803, -73.98463202553815, 11.0], [40.80872296900465, -73.86498144465455, 271.0], [40.63494665055749, -73.76998248459255, 225.0], [40.71545919495178, -73.78625345617166, 280.0], [40.70766328143659, -73.96944801770442, 46.0], [40.68895748109208, -73.91502009404968, 73.0], [40.81480784719429, -73.98167680151965, 144.0], [40.69784109035334, -73.77825616494698, 26.0], [40.88394825410715, -73.95429461937061, 299.0], [40.70454453650301, -73.72546494370914, 154.0], [40.83381286787973, -73.82147978261627, 151.0], [40.66622594897056, -73.84296010522051, 150.0], [40.68549877033832, -73.95575313900638, 224.0], [40.7388168470776, -73.98731052988889, 293.0], [40.82497792746277, -73.89713429620456, 57.0], [40.72853682123984, -73.85422661291005, 286.0], [40.76102610159575, -73.72598072831252, 73.0], [40.8870888492091, -73.72519380384816, 14.0], [40.852932854711646, -73.81839546522251, 265.0], [40.64387109029081, -73.79037939565546, 56.0], [40.84231055644127, -73.86010245731221, 144.0], [40.804200223789366, -73.8401920712093, 115.0], [40.73202113217576, -73.71380844481168, 11.0], [40.663336176926336, -73.91330114985531, 234.0], [40.769751027371576, -73.72110691296407, 246.0], [40.69700564791232, -73.9469249441207, 13.0], [40.856072773228384, -73.79000289053337, 176.0], [40.86917162786176, -73.91349431519171, 176.0], [40.693590466802185, -73.79771272493758, 95.0], [40.80450052449834, -73.95187970227337, 54.0], [40.86

# %% [markdown]
# ### **Identify Congestion Hotspots with K-Means**

# %%
high_congestion_df = df[df['Traffic_Condition'] == 'High'].copy()

# Check if there are enough high congestion points to cluster
if len(high_congestion_df) >= 5:
    print(f"Found {len(high_congestion_df)} high-congestion events. Proceeding with clustering.")

    # Prepare the geographical data for clustering
    coords = high_congestion_df[['Latitude', 'Longitude']]

    # Apply the K-Means algorithm to find 5 hotspots
    kmeans = KMeans(n_clusters=5, random_state=42, n_init='auto')
    high_congestion_df['cluster'] = kmeans.fit_predict(coords)

    hotspots = kmeans.cluster_centers_

    # Visualize the hotspots on a new map
    hotspot_map = folium.Map(location=map_center, zoom_start=12)

    # Add the cluster centers (hotspots) to the map as markers
    for i, hotspot in enumerate(hotspots):
        folium.Marker(
            location=[hotspot[0], hotspot[1]],
            popup=f"Congestion Hotspot #{i+1}",
            tooltip=f"Identified Center of High Congestion",
            icon=folium.Icon(color='red', icon='info-sign')
        ).add_to(hotspot_map)

    print("\nDisplaying map with identified congestion hotspots from your data.")
    display(hotspot_map)

else:
    print(f"Only found {len(high_congestion_df)} high-congestion data points. This is not enough for clustering. Consider reducing 'n_clusters' or checking your data.")
# Out:
# Found 3166 high-congestion events. Proceeding with clustering.
#
# Displaying map with identified congestion hotspots from your data.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00b3fc3b3811c9b9236e5007d1e20319 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00b3fc3b3811c9b9236e5007d1e20319&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00b3fc3b3811c9b9236e5007d1e20319 = L.map(
#                 &quot;map_00b3fc3b3811c9b9236e5007d1e20319&quot;,
#                 {
#                     center: [40.74964523031779, -73.847433411381],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f30ddb1fdaf9ec065514c2b0f9081121 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f30ddb1fdaf9ec065514c2b0f9081121.addTo(map_00b3fc3b3811c9b9236e5007d1e20319);
#
#
#             var marker_97878d786af07a88deeac0dd1052cf07 = L.marker(
#                 [40.74398795753008, -73.84850455810215],
#                 {
# }
#             ).addTo(map_00b3fc3b3811c9b9236e5007d1e20319);
#
#
#             var icon_1466f318a7b0e91cca023faaf7a8543a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ffcff497c6b2ad93a4c7a82031d79ebd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5073f8e802d16570621833154c4dc999 = $(`&lt;div id=&quot;html_5073f8e802d16570621833154c4dc999&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congestion Hotspot #1&lt;/div&gt;`)[0];
#                 popup_ffcff497c6b2ad93a4c7a82031d79ebd.setContent(html_5073f8e802d16570621833154c4dc999);
#
#
#
#         marker_97878d786af07a88deeac0dd1052cf07.bindPopup(popup_ffcff497c6b2ad93a4c7a82031d79ebd)
#         ;
#
#
#
#
#             marker_97878d786af07a88deeac0dd1052cf07.bindTooltip(
#                 `&lt;div&gt;
#                      Identified Center of High Congestion
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_97878d786af07a88deeac0dd1052cf07.setIcon(icon_1466f318a7b0e91cca023faaf7a8543a);
#
#
#             var marker_91b4d75742fac9a42dd5a0fd30a83a6b = L.marker(
#                 [40.83432631771697, -73.7676350993978],
#                 {
# }
#             ).addTo(map_00b3fc3b3811c9b9236e5007d1e20319);
#
#
#             var icon_0a78dcf248ee27614f43b13eeb316d41 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2def6271e17a22133eaf92617d67844a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d62159cd4b8878d786fb6b0a41d8a84 = $(`&lt;div id=&quot;html_9d62159cd4b8878d786fb6b0a41d8a84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congestion Hotspot #2&lt;/div&gt;`)[0];
#                 popup_2def6271e17a22133eaf92617d67844a.setContent(html_9d62159cd4b8878d786fb6b0a41d8a84);
#
#
#
#         marker_91b4d75742fac9a42dd5a0fd30a83a6b.bindPopup(popup_2def6271e17a22133eaf92617d67844a)
#         ;
#
#
#
#
#             marker_91b4d75742fac9a42dd5a0fd30a83a6b.bindTooltip(
#                 `&lt;div&gt;
#                      Identified Center of High Congestion
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_91b4d75742fac9a42dd5a0fd30a83a6b.setIcon(icon_0a78dcf248ee27614f43b13eeb316d41);
#
#
#             var marker_207a0b5f7dad8227b114a1dfd241aa35 = L.marker(
#                 [40.83360686306561, -73.93399066526008],
#                 {
# }
#             ).addTo(map_00b3fc3b3811c9b9236e5007d1e20319);
#
#
#             var icon_7fbe2072b778afb5b65d61cde165121b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e3fe21f54e7837276a936ed2b31aa0f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_788b54

# %% [markdown]
# ### **Analyze Congestion vs. Time of Day**

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
df.dropna(subset=['Timestamp'], inplace=True)
df['Hour'] = df['Timestamp'].dt.hour

# Calculate the counts of each traffic condition per hour
hourly_counts = df.groupby('Hour')['Traffic_Condition'].value_counts().unstack().fillna(0)

# Create the line plot for High vs. Low congestion
plt.figure(figsize=(15, 7))
plt.plot(hourly_counts.index, hourly_counts.get('High', 0), color='red', marker='o', linestyle='-', label='High Congestion')
plt.plot(hourly_counts.index, hourly_counts.get('Low', 0), color='blue', marker='.', linestyle='--', label='Low Congestion')

plt.title('High vs. Low Congestion by Time of Day', fontsize=16)
plt.xlabel('Hour of the Day (0-23)', fontsize=12)
plt.ylabel('Number of Records (Frequency)', fontsize=12)
plt.xticks(ticks=range(0, 24))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ### **Pathway Efficiency Scoring Model**

# %%
# Create a mapping for Traffic_Condition
traffic_map = {'Low': 3, 'Medium': 2, 'High': 1}
df['Traffic_Value'] = df['Traffic_Condition'].map(traffic_map)

# Normalize Traffic Speed for fair comparison
min_speed = df['Traffic_Speed_kmh'].min()
max_speed = df['Traffic_Speed_kmh'].max()
df['Normalized_Speed'] = (df['Traffic_Speed_kmh'] - min_speed) / (max_speed - min_speed)

# Calculate the final Efficiency Score
df['Efficiency_Score'] = df['Traffic_Value'] * df['Normalized_Speed']

print("--- Pathway Efficiency Score Calculation ---")
print(df[['Traffic_Condition', 'Traffic_Value', 'Traffic_Speed_kmh', 'Normalized_Speed', 'Efficiency_Score']].head())
print(f"\nAverage Efficiency Score across all data points: {df['Efficiency_Score'].mean():.3f}")
# Out:
# --- Pathway Efficiency Score Calculation ---
#   Traffic_Condition  Traffic_Value  Traffic_Speed_kmh  Normalized_Speed  \
# 0              High              1          49.893435          0.598584
# 1              High              1          22.383965          0.231765
# 2              High              1          46.889699          0.558531
# 3              High              1           5.730536          0.009704
# 4               Low              3          61.348034          0.751322
#
#    Efficiency_Score
# 0          0.598584
# 1          0.231765
# 2          0.558531
# 3          0.009704
# 4          2.253967
#
# Average Efficiency Score across all data points: 0.765

# %% [markdown]
# ### **Smart Pathway Re-design based on Hotspots**

# %%
def get_hotspot_efficiency(hotspot_coords, df, radius=0.01):
    """Calculates the average efficiency score in the vicinity of a hotspot."""
    lat, lon = hotspot_coords

    # Filter data points within a small geographical radius of the hotspot
    nearby_data = df[
        (df['Latitude'] >= lat - radius) & (df['Latitude'] <= lat + radius) &
        (df['Longitude'] >= lon - radius) & (df['Longitude'] <= lon + radius)
    ]

    if len(nearby_data) > 0:
        return nearby_data['Efficiency_Score'].mean(), len(nearby_data)
    else:
        return 0, 0

print("\n--- Hotspot Efficiency Analysis and Pathway Proposal ---")
pathway_proposals = []


map_center = [df['Latitude'].mean(), df['Longitude'].mean()]

for i, hotspot in enumerate(hotspots):
    avg_efficiency, count = get_hotspot_efficiency(hotspot, df)

    if avg_efficiency > 0.6:
        proposal = "Optimal flow. Minor improvements only."
        action_color = 'green'
    elif avg_efficiency > 0.4:
        proposal = "Moderate congestion. Suggest real-time traffic light optimization."
        action_color = 'orange'
    else:
        proposal = "**Critical Congestion.** Propose immediate pathway re-design (e.g., add by-pass or dedicated flow lane)."
        action_color = 'red'

    pathway_proposals.append({
        'Hotspot_ID': i + 1,
        'Latitude': hotspot[0],
        'Longitude': hotspot[1],
        'Avg_Efficiency_Score': f"{avg_efficiency:.3f}",
        'Data_Points_Nearby': count,
        'Proposal': proposal,
        'Color': action_color
    })

# Display the final proposals as a DataFrame
proposal_df = pd.DataFrame(pathway_proposals)
print(proposal_df.to_markdown(index=False))

# Visualize the proposals on a map
proposal_map = folium.Map(location=map_center, zoom_start=12)

# Add the cluster centers with colored markers based on their proposal
for row in proposal_df.itertuples():
    folium.Marker(
        location=[row.Latitude, row.Longitude],
        popup=f"Hotspot #{row.Hotspot_ID}<br>Avg. Efficiency: {row.Avg_Efficiency_Score}<br>Proposal: {row.Proposal}",
        tooltip=f"Hotspot {row.Hotspot_ID}",
        icon=folium.Icon(color=row.Color, icon='cogs' if row.Color == 'red' else 'leaf')
    ).add_to(proposal_map)

print("\nDisplaying map with proposed infrastructure actions.")
display(proposal_map)
# Out:
# --- Hotspot Efficiency Analysis and Pathway Proposal ---
# |   Hotspot_ID |   Latitude |   Longitude |   Avg_Efficiency_Score |   Data_Points_Nearby | Proposal                                                           | Color   |
# |-------------:|-----------:|------------:|-----------------------:|---------------------:|:-------------------------------------------------------------------|:--------|
# |            1 |    40.744  |    -73.8485 |                  0.639 |                   21 | Optimal flow. Minor improvements only.                             | green   |
# |            2 |    40.8343 |    -73.7676 |                  0.584 |                   20 | Moderate congestion. Suggest real-time traffic light optimization. | orange  |
# |            3 |    40.8336 |    -73.934  |                  0.824 |                   26 | Optimal flow. Minor improvements only.                             | green   |
# |            4 |    40.6661 |    -73.9315 |                  0.834 |                   12 | Optimal flow. Minor improvements only.                             | green   |
# |            5 |    40.6698 |    -73.7633 |                  0.929 |                   24 | Optimal flow. Minor improvements only.                             | green   |
#
# Displaying map with proposed infrastructure actions.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c23ad728805fdfd36e214110b3dc3b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c23ad728805fdfd36e214110b3dc3b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c23ad728805fdfd36e214110b3dc3b2 = L.map(
#                 &quot;map_3c23ad728805fdfd36e214110b3dc3b2&quot;,
#                 {
#                     center: [40.74964523031779, -73.847433411381],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0caea1d244f30a7d0e43378cce833c46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0caea1d244f30a7d0e43378cce833c46.addTo(map_3c23ad728805fdfd36e214110b3dc3b2);
#
#
#             var marker_3f48c1ac9f419d12ad53e725a5e4c2d7 = L.marker(
#                 [40.74398795753008, -73.84850455810215],
#                 {
# }
#             ).addTo(map_3c23ad728805fdfd36e214110b3dc3b2);
#
#
#             var icon_01c0ad367e8504e19c417ea35bde130b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;leaf&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_63a609a1077b9deb850e78deb4299eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50f00999cab58c3d2497f1bcc2942af7 = $(`&lt;div id=&quot;html_50f00999cab58c3d2497f1bcc2942af7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot #1&lt;br&gt;Avg. Efficiency: 0.639&lt;br&gt;Proposal: Optimal flow. Minor improvements only.&lt;/div&gt;`)[0];
#                 popup_63a609a1077b9deb850e78deb4299eb1.setContent(html_50f00999cab58c3d2497f1bcc2942af7);
#
#
#
#         marker_3f48c1ac9f419d12ad53e725a5e4c2d7.bindPopup(popup_63a609a1077b9deb850e78deb4299eb1)
#         ;
#
#
#
#
#             marker_3f48c1ac9f419d12ad53e725a5e4c2d7.bindTooltip(
#                 `&lt;div&gt;
#                      Hotspot 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3f48c1ac9f419d12ad53e725a5e4c2d7.setIcon(icon_01c0ad367e8504e19c417ea35bde130b);
#
#
#             var marker_f3d252b568318bdef8657bc3e50336ea = L.marker(
#                 [40.83432631771697, -73.7676350993978],
#                 {
# }
#             ).addTo(map_3c23ad728805fdfd36e214110b3dc3b2);
#
#
#             var icon_0c7b4cc84ad45f89c822afc0b3876086 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;leaf&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a5e1d14beb5e4bf8df09250d36e0ba01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7fc57577c555cc2c027f58d92e207f0 = $(`&lt;div id=&quot;html_f7fc57577c555cc2c027f58d92e207f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot #2&lt;br&gt;Avg. Efficiency: 0.584&lt;br&gt;Proposal: Moderate congestion. Suggest real-time traffic light optimization.&lt;/div&gt;`)[0];
#                 popup_a5e1d14beb5e4bf8df09250d36e0ba01.setContent(html_f7fc57577c555cc2c027f58d92e207f0);
#
#
#
#         marker_f3d252b568318bdef8657bc3e50336ea.bindPopup(popup_a5e1d14beb5e4bf8df09250d36e0ba01)
#         ;
#
#
#
#
#             marker_f3d252b568318bdef8657bc3e50336ea.bindTooltip(
#                 `&lt;div&gt;
#                      Hotspot 2
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f3d252b568318bdef8657bc3e50336ea.setIcon(icon_0c7b4cc84ad45f89c822afc0b3876086);
#
#
#             var marker_dad0eb97ce21f156edfa955cedf271af = L.marker(
#                 [40.83360686306561, -73.93399066526008],
#                 {
# }
#             ).addTo(map_3c23ad728805fdfd36e214110b3dc3b2);
#
#
#             var icon_3687b0b4027a37f59997face90e20722 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;leaf&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c11f01b4ec9264f7eba15
